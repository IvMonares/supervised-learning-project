# %% [markdown]
# # DTSA 5509 Supervised Learning Final Project
#
# ## Background
#
# <!-- TODO Add data description -->
#
# Data was obtained from UCI Machine Learning Repository at [https://archive.ics.uci.edu/ml/datasets/Room+Occupancy+Estimation](https://archive.ics.uci.edu/ml/datasets/Room+Occupancy+Estimation)

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Set color map to have light blue background
sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('./Occupancy_Estimation.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10129 entries, 0 to 10128
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  10129 non-null  object
#  1   Time                  10129 non-null  object
#  2   S1_Temp               10129 non-null  float64
#  3   S2_Temp               10129 non-null  float64
#  4   S3_Temp               10129 non-null  float64
#  5   S4_Temp               10129 non-null  float64
#  6   S1_Light              10129 non-null  int64
#  7   S2_Light              10129 non-null  int64
#  8   S3_Light              10129 non-null  int64
#  9   S4_Light              10129 non-null  int64
#  10  S1_Sound              10129 non-null  float64
#  11  S2_Sound              10129 non-null  float64
#  12  S3_Sound              10129 non-null  float64
#  13  S4_Sound              10129 non-null  float64
#  14  S5_CO2                10129 non-null  int64
# ...

# %% [markdown]
# ## Data Cleaning
#
# <!-- TODO -->
# Data is already clean.
#
# ## Data Correlation

# %%
correlation = df.corr()
correlation["Room_Occupancy_Count"]
# Out:
# S1_Temp                 0.700868
# S2_Temp                 0.671263
# S3_Temp                 0.652047
# S4_Temp                 0.526509
# S1_Light                0.849058
# S2_Light                0.788764
# S3_Light                0.793081
# S4_Light                0.355715
# S1_Sound                0.573748
# S2_Sound                0.557853
# S3_Sound                0.531685
# S4_Sound                0.460287
# S5_CO2                  0.660144
# S5_CO2_Slope            0.601105
# S6_PIR                  0.633133
# S7_PIR                  0.695138
# Room_Occupancy_Count    1.000000
# Name: Room_Occupancy_Count, dtype: float64

# %%
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %%
columns = ["S1_Temp", "S2_Temp", "S3_Temp", "S4_Temp"]
g = sns.pairplot(df.filter(items=columns), diag_kind="kde")
g.set(xticklabels=[], yticklabels=[])

# %%
columns = ["S1_Light", "S2_Light", "S3_Light", "S4_Light"]
g = sns.pairplot(df.filter(items=columns), diag_kind="kde")
g.set(xticklabels=[], yticklabels=[])

# %%
columns = ["S1_Sound", "S2_Sound", "S3_Sound", "S4_Sound"]
g = sns.pairplot(df.filter(items=columns), diag_kind="kde")
g.set(xticklabels=[], yticklabels=[])

# %%
columns = ["S5_CO2", "S5_CO2_Slope", "S6_PIR", "S7_PIR"]
g = sns.pairplot(df.filter(items=columns), diag_kind="kde")
g.set(xticklabels=[], yticklabels=[])

# %%
columns = ["S1_Temp", "S3_Light", "S1_Sound", "S5_CO2", "S7_PIR"]
g = sns.pairplot(df.filter(items=columns), diag_kind="kde")
g.set(xticklabels=[], yticklabels=[])

# %% [markdown]
# ## Models for Analysis
#
# <!-- TODO - include Complete Case Analysis suitability-->
#
# Models used to predict the dataset's behavior can be found at the following files:
# * Multi-linear Regression.ipynb
